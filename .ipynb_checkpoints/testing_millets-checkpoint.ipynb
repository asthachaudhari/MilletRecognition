# %% [markdown]
# ##Importing libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %% [markdown]
# ##Loading model

# %%
cnn = tf.keras.models.load_model('/content/trained_model (1).h5')

# %% [markdown]
# ##Visualising and Performing Prediction on Single image

# %%
#Test Image Visualization
import cv2
image_path = '/content/drive/MyDrive/millets/test/Amarnath_millet/img_1.jpg'
# Reading an image in default mode
img = cv2.imread(image_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB) #Converting BGR to RGB
# Displaying the image
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(64,64))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr])  # Convert single image to a batch.
predictions = cnn.predict(input_arr)
# Out:
# 1/1 [==============================] - 0s 373ms/step

# %%
print(predictions)
# Out:
# [[1.0000000e+00 6.0816494e-13 5.4778129e-16 1.9127010e-10 8.5653750e-15
#   3.3171432e-12 5.6311895e-12 1.7326620e-09 1.7243973e-12]]

# %%
test_set = tf.keras.utils.image_dataset_from_directory(
    '/content/drive/MyDrive/millets/test',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(64, 64),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 136 files belonging to 9 classes.

# %%
test_set.class_names
# Out:
# ['Amarnath_millet',
#  'Buckwheat_millet',
#  'Finger_millet',
#  'Foxtail_millet',
#  'KonkanRedRice',
#  'Little_millet',
#  'Niger_seeds',
#  'Pearl_millet',
#  'Sorghum_millet']

# %%
result_index = np.argmax(predictions) #Return index of max element
print(result_index)
# Out:
# 0

# %%
# Displaying the image
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
#Single image Prediction
print("The millet is {}".format(test_set.class_names[result_index]))
# Out:
# The millet is Amarnath_millet

# %%
test_set.class_names
# Out:
# ['Amarnath_millet',
#  'Buckwheat_millet',
#  'Finger_millet',
#  'Foxtail_millet',
#  'KonkanRedRice',
#  'Little_millet',
#  'Niger_seeds',
#  'Pearl_millet',
#  'Sorghum_millet']

# %%
file=open("labels.txt","w")
for i in test_set.class_names:
  file.write(i+'\n')
file.close()

# %%
with open("labels.txt") as f:
  content= f.readlines()

# %%
content
# Out:
# ['Amarnath_millet\n',
#  'Buckwheat_millet\n',
#  'Finger_millet\n',
#  'Foxtail_millet\n',
#  'KonkanRedRice\n',
#  'Little_millet\n',
#  'Niger_seeds\n',
#  'Pearl_millet\n',
#  'Sorghum_millet\n']

# %%
l= []
for i in content:
  l.append(i[:-1])
